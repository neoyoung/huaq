# %% [markdown]
# # 散点图

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n=500
x, y = np.random.rand(2, n)
size = 200.0 * np.random.rand(n)
fig1 = plt.figure(figsize=(15,8))
ax1 = fig1.add_axes([0.1,0.1,0.4,0.3])
ax1.scatter(x,y,s=size,c='r',edgecolor='k',alpha=0.5,marker='o',label='AAA')
ax1.legend()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/E6089B1737F8439883AE2A8DB2B8471F/r5g131zv26.png">

# %%
n=15
x, y = np.random.rand(2, n)
size = 200.0 * np.random.rand(n)
fig1 = plt.figure(figsize=(15,8))
ax1 = fig1.add_axes([0.1,0.1,0.4,0.3])
ax1.scatter(x,y,s=size,c='r',edgecolor='k',alpha=0.5,marker='o',label='AAA')
ax1.legend()
for i in range(n):
    ax1.text(x[i],y[i],'{}'.format(i),fontsize=12)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/704702662D814317891E592D4E2E9E61/r5g16j9wpb.png">

# %%
import pandas as pd
import numpy as np
from eofs.standard import Eof
t = np.zeros((5,825))
f = pd.read_csv('/home/mw/input/moyu1828/1957_2012_tm_year_avg.txt',sep = '\s+',names=['station','lat','lon','alt','year','tm'], na_values=-99.90)
for i in range(2008,2012):
    data = f.loc[f.year==i]
    data = data.dropna(axis=0,how='any')
    t[i-2008] = data.tm.values   
lat = data.lat.values/100
lon = data.lon.values/100 

eof = Eof(t)
t_eof = eof.eofsAsCorrelation(neofs=2)
t_pc = eof.pcs(npcs=2, pcscaling=1)
t_var = eof.varianceFraction(neigs=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-d862d341a9c4> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from eofs.standard import Eof
#       4 t = np.zeros((5,825))
#       5 f = pd.read_csv('/home/mw/input/moyu8092/1957_2012_tm_year_avg.txt',sep = '\s+',names=['station','lat','lon','alt','year','tm'], na_values=-99.90)
#
# ModuleNotFoundError: No module named 'eofs'

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.mpl.ticker as cticker

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.4],projection = ccrs.PlateCarree(central_longitude=90))
leftlon, rightlon, lowerlat, upperlat = (60,150,20,80)
img_extent = [leftlon, rightlon, lowerlat, upperlat]
ax1.set_extent(img_extent, crs=ccrs.PlateCarree())
ax1.set_xticks(np.arange(60,150+30,30), crs=ccrs.PlateCarree())
ax1.set_yticks(np.arange(0,60+30,30), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
lat_formatter = cticker.LatitudeFormatter()
ax1.xaxis.set_major_formatter(lon_formatter)
ax1.yaxis.set_major_formatter(lat_formatter)
c1 = ax1.scatter(lon,lat,s=2, c=t_eof[0],transform=ccrs.PlateCarree(),vmin=-1.6,vmax=1.6 ,cmap=plt.cm.jet)
position=fig.add_axes([0.35, 0.02,  0.35, 0.025])
fig.colorbar(c1,cax=position,orientation='horizontal',format='%.2f',)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/77B186E805014ACE83FE669B9F722859/r45o91559q.png">
